# %%
bk_list = []
bk_int = []
weight = 5

# %%
def RGBQUAD(QUAD_list):
  for i in range(0,0xff + 1 ,1):
    QUAD_list.append(i) #b
    QUAD_list.append(i) #g
    QUAD_list.append(i) #r
    QUAD_list.append(0x00) #reserve

# %%
with open("testgray.bmp", "rb") as f:
    byte = f.read(1)
    while byte != b"":
        # Do stuff with byte.
        bk_list.append(byte)
        byte = f.read(1)

# %%
print(bk_list[:])
# Out:
# [b'B', b'M', b'N', b'\xfa', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'6', b'\x04', b'\x00', b'\x00', b'(', b'\x00', b'\x00', b'\x00', b'\xfa', b'\x00', b'\x00', b'\x00', b'\xfa', b'\x00', b'\x00', b'\x00', b'\x01', b'\x00', b'\x08', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x01', b'\x01', b'\x01', b'\x00', b'\x02', b'\x02', b'\x02', b'\x00', b'\x03', b'\x03', b'\x03', b'\x00', b'\x04', b'\x04', b'\x04', b'\x00', b'\x05', b'\x05', b'\x05', b'\x00', b'\x06', b'\x06', b'\x06', b'\x00', b'\x07', b'\x07', b'\x07', b'\x00', b'\x08', b'\x08', b'\x08', b'\x00', b'\t', b'\t', b'\t', b'\x00', b'\n', b'\n', b'\n', b'\x00', b'\x0b', b'\x0b', b'\x0b', b'\x00', b'\x0c', b'\x0c', b'\x0c', b'\x00', b'\r', b'\r', b'\r', b'\x00', b'\x0e', b'\x0e', b'\x0e', b'\x00', b'\x
# ...

# %%
dot_list = []
dot_int = []

# %%
with open("dot.bmp", "rb") as f:
    byte = f.read(1)
    while byte != b"":
        # Do stuff with byte.
        dot_list.append(byte)
        byte = f.read(1)

# %%
print(dot_list[1077:])
print(len(dot_list[1077:]))
# Out:
# [b'\x00', b'\xe5', b'\xd1', b'\xb8', b'\x9b', b'\x7f', b'e', b'P', b'A', b'8', b'7', b'<', b'F', b'S', b'a', b'n', b'y', b'\x81', b'\x85', b'\x84', b'\x80', b'x', b'p', b'g', b'`', b'\\', b']', b'b', b'l', b'{', b'\x8e', b'\xa2', b'\xb8', b'\xcc', b'\xdd', b'\xea', b'\xf2', b'\xf2', b'\xec', b'\xe0', b'\xce', b'\xb7', b'\x9d', b'\x82', b'h', b'P', b';', b'+', b'!', b'\x1d', b'\x1e', b'%', b'0', b'=', b'L', b'[', b'h', b't', b'{', b'\x7f', b'~', b'y', b'p', b'e', b'W', b'H', b'9', b'+', b' ', b'\x17', b'\x12', b'\x11', b'\x15', b'\x1c', b'&', b'3', b'C', b'S', b'd', b't', b'\x82', b'\x8e', b'\x97', b'\x9d', b'\x9f', b'\x9d', b'\x98', b'\x90', b'\x86', b'y', b'k', b'\\', b'M', b'>', b'1', b'%', b'\x1c', b'\x15', b'\x10', b'\x0e', b'\x0e', b'\x11', b'\x15', b'\x1c', b'$', b'.', b'8', b'C', b'M', b'X', b'b', b'k', b't', b'{', b'\x82', b'\x87', b'\x8c', b'\x8f', b'\x92', b'\x94', b'\x95', b'\x96', b'\x97', b'\x97', b'\x97', b'\x97', b'\x97', b'\x97', b'\x97', b'\x97', b'\x96', b'\x95', b'
# ...

# %%
for i in range(1078,len(dot_list)):
  dot_int.append(int.from_bytes(dot_list[i], "big"))
  bk_int.append(int.from_bytes(bk_list[i], "big"))

# %%
normolize = []
normolize.append(0x42)
normolize.append(0x4D)

normolize.append(0x4e)
normolize.append(0xf8)
normolize.append(0x00)
normolize.append(0x00)

normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00) #reserve

normolize.append(0x36)
normolize.append(0x04)
normolize.append(0x00)
normolize.append(0x00) #offbyte

normolize.append(0x28)
normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00) #bisize

normolize.append(0xfa)
normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00) #width = 255

normolize.append(0xfa)
normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00) #height = 10

normolize.append(0x01)
normolize.append(0x00) #plane

normolize.append(0x08)
normolize.append(0x00) #bit count

normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00) #compression

normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00) #compression size

normolize.append(0x13)
normolize.append(0x0b)
normolize.append(0x00)
normolize.append(0x00) #horizon

normolize.append(0x13)
normolize.append(0x0b)
normolize.append(0x00)
normolize.append(0x00) #vertical

normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00) #color used 

normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00)
normolize.append(0x00) #color important
# for i in range(1078):
#   normolize.append(dot_list[i])

# %%
temp = []
for i in range(len(bk_int)):
  temp.append( weight * bk_int[i] +   dot_int[i])

# %%
MAX = max(temp)

# %%
RGBQUAD(normolize)

# %%
for i in range(len(bk_int)):
  normolize.append(int((( weight * bk_int[i] +  dot_int[i]) / MAX) * 255))

# %%
for i in range(10):
  # print(bk_int[i])
  # print(dot_int[i])
  print(bytes(int(((bk_int[i] + dot_int[i]) / MAX) * 255).to_bytes(1, 'big')))
# Out:
# b'?'
# b'<'
# b'8'
# b'3'
# b'.'
# b'*'
# b"'"
# b'$'
# b'#'
# b'"'

# %%
print(max(normolize))
print(bk_list[0:10])
# Out:
# 255
# [b'B', b'M', b'N', b'\xfa', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00', b'\x00']

# %%
print(len(normolize))
# Out:
# 64078

# %%
print(normolize[-2])
# Out:
# 0

# %%
for i in range(len(normolize)):
  # print(bk_int[i])
  # print(dot_int[i])
  if(i == 61440):
    print(normolize[i])
# Out:
# 122

# %%
file_merge = open("./merge1.bmp","wb")

# %%
file_merge.write(bytes(normolize))
# Out:
# 64078

# %%
file_merge.close()

# %%
test = []

# %%
with open("merge1.bmp", "rb") as f:
    byte = f.read(1)
    while byte != b"":
        # Do stuff with byte.
        # print(byte)
        test.append(byte)
        byte = f.read(1)

# %%
print(len(test))
# Out:
# 64078
